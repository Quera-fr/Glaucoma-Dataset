# %%
import shutil, os

for filename in os.listdir('Validation/Glaucoma_Negative'):
    shutil.copy('Validation/Glaucoma_Negative/'+filename, 
                'Validation/negative_'+filename)
    
for filename in os.listdir('Validation/Glaucoma_Positive'):
    shutil.copy('Validation/Glaucoma_Positive/'+filename, 
                'Validation/positive_'+filename)
    
for filename in os.listdir('Train/Glaucoma_Negative'):
    shutil.copy('Train/Glaucoma_Negative/'+filename, 
                'Train/negative_'+filename)
    
for filename in os.listdir('Train/Glaucoma_Positive'):
    shutil.copy('Train/Glaucoma_Positive/'+filename, 
                'Train/positive_'+filename)

# %%
shutil.copy()
